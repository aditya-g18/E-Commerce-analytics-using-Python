# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#to show the graph in the notebook
# %matplotlib inline    
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ADITYA GUPTA\Downloads\Data\Sample - Superstore.csv", encoding='latin1')
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df[df['Customer ID'].duplicated()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 6          7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7          8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8          9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df['Customer ID'].drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df[['Ship Date', 'Order Date']]
# Out:
#        Ship Date  Order Date
# 0     11/11/2016   11/8/2016
# 1     11/11/2016   11/8/2016
# 2      6/16/2016   6/12/2016
# 3     10/18/2015  10/11/2015
# 4     10/18/2015  10/11/2015
# ...          ...         ...
# 9989   1/23/2014   1/21/2014
# 9990    3/3/2017   2/26/2017
# 9991    3/3/2017   2/26/2017
# 9992    3/3/2017   2/26/2017
# 9993    5/9/2017    5/4/2017
#
# [9994 rows x 2 columns]

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%m/%d/%Y')
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   datetime64[us]
#  3   Ship Date      9994 non-null   datetime64[us]
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %%
df.describe()
# Out:
#             Row ID                  Order Date                   Ship Date  \
# count  9994.000000                        9994                        9994
# mean   4997.500000  2016-04-30 00:07:12.259355  2016-05-03 23:06:58.571142
# min       1.000000         2014-01-03 00:00:00         2014-01-07 00:00:00
# 25%    2499.250000         2015-05-23 00:00:00         2015-05-27 00:00:00
# 50%    4997.500000         2016-06-26 00:00:00         2016-06-29 00:00:00
# 75%    7495.750000         2017-05-14 00:00:00         2017-05-18 00:00:00
# max    9994.000000         2017-12-30 00:00:00         2018-01-05 00:00:00
# std    2885.163629                         NaN                         NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %%
df['Order Year'] = df['Order Date'].dt.year
df['Order Month'] = df['Order Date'].dt.month_name().str[:3]
df['Order Week'] = df['Order Date'].dt.dayofweek
df.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Year  Order Month  Order Week
# 0  41.9136        2016          Nov           1
#
# [1 rows x 24 columns]

# %% [markdown]
# # Monthly Sales Analysis

# %%
Sales_By_Month = df.groupby('Order Month')['Sales'].sum().reset_index()
Sales_By_Month
# Out:
#    Order Month        Sales
# 0          Apr  137762.1286
# 1          Aug  159044.0630
# 2          Dec  325293.5035
# 3          Feb   59751.2514
# 4          Jan   94924.8356
# 5          Jul  147238.0970
# 6          Jun  152718.6793
# 7          Mar  205005.4888
# 8          May  155028.8117
# 9          Nov  352461.0710
# 10         Oct  200322.9847
# 11         Sep  307649.9457

# %%
plt.figure(figsize=(6,4))

Sales_By_Month.plot(x='Order Month', y='Sales')
plt.title('Monthly Sales Analysis')
plt.xlabel('Month')
plt.ylabel('Slaes')
# Out:
# Text(0, 0.5, 'Slaes')

# %% [markdown]
# # Sales By Categories

# %%
Sales_by_Categorie = df.groupby('Category')['Sales'].sum().reset_index()
Sales_by_Categorie
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
Sales_by_Categorie.plot.bar(x='Category', y='Sales', color='salmon', edgecolor='red')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# # Sales By Sub-Catogries

# %%
df.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Year  Order Month  Order Week
# 0  41.9136        2016          Nov           1
#
# [1 rows x 24 columns]

# %%
Sales_By_Sub_Categories = df.groupby('Sub-Category')['Sales'].sum().reset_index()
Sales_By_Sub_Categories
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27118.7920
# 3       Binders  203412.7330
# 4     Bookcases  114879.9963
# 5        Chairs  328449.1030
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91705.1640
# 10       Labels   12486.3120
# 11     Machines  189238.6310
# 12        Paper   78479.2060
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
Sales_By_Sub_Categories.plot.bar(x='Sub-Category', y='Sales', color='lightblue', edgecolor='blue')
plt.legend().remove()

plt.show()

# %% [markdown]
# # Monthly Profit Analysis

# %%
df[['Profit','Order Month']]
# Out:
#         Profit Order Month
# 0      41.9136         Nov
# 1     219.5820         Nov
# 2       6.8714         Jun
# 3    -383.0310         Oct
# 4       2.5164         Oct
# ...        ...         ...
# 9989    4.1028         Jan
# 9990   15.6332         Feb
# 9991   19.3932         Feb
# 9992   13.3200         Feb
# 9993   72.9480         May
#
# [9994 rows x 2 columns]

# %%
Monhly_profit_Analysis = df.groupby('Order Month')['Profit'].sum().reset_index()
Monhly_profit_Analysis
# Out:
#    Order Month      Profit
# 0          Apr  11587.4363
# 1          Aug  21776.9384
# 2          Dec  43369.1919
# 3          Feb  10294.6107
# 4          Jan   9134.4461
# 5          Jul  13832.6648
# 6          Jun  21285.7954
# 7          Mar  28594.6872
# 8          May  22411.3078
# 9          Nov  35468.4265
# 10         Oct  31784.0413
# 11         Sep  36857.4753

# %%
Monhly_profit_Analysis.plot.bar(x='Order Month', y='Profit', color='lightgreen', edgecolor='green')
plt.legend().remove()

# %% [markdown]
# # Profit By Category And Sub-Category

# %%
df.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Year  Order Month  Order Week
# 0  41.9136        2016          Nov           1
#
# [1 rows x 24 columns]

# %%
Profit_by_Categorie = df.groupby('Category')['Profit'].sum().reset_index()
Profit_by_Categorie
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
Profit_by_Categorie.set_index('Category')['Profit'].plot.pie(autopct='%1.1f%%',wedgeprops={'width':0.5}, colors = ['#ff9999','#66b3ff','#99ff99'])

plt.show()

# %%
Profit_by_Sub_Categorie = df.groupby('Sub-Category')['Profit'].sum().reset_index()
Profit_by_Sub_Categorie
# Out:
#    Sub-Category      Profit
# 0   Accessories  41936.6357
# 1    Appliances  18138.0054
# 2           Art   6527.7870
# 3       Binders  30221.7633
# 4     Bookcases  -3472.5560
# 5        Chairs  26590.1663
# 6       Copiers  55617.8249
# 7     Envelopes   6964.1767
# 8     Fasteners    949.5182
# 9   Furnishings  13059.1436
# 10       Labels   5546.2540
# 11     Machines   3384.7569
# 12        Paper  34053.5693
# 13       Phones  44515.7306
# 14      Storage  21278.8264
# 15     Supplies  -1189.0995
# 16       Tables -17725.4811

# %%
df['Profit'].head(5)
# Out:
# 0     41.9136
# 1    219.5820
# 2      6.8714
# 3   -383.0310
# 4      2.5164
# Name: Profit, dtype: float64

# %%
df[df['Profit']<0].head(4)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 14      15  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 15      16  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 23      24  US-2017-156909 2017-07-16 2017-07-18    Second Class    SF-20065
#
#       Customer Name      Segment        Country             City  ...  \
# 3    Sean O'Donnell     Consumer  United States  Fort Lauderdale  ...
# 14    Harold Pawlan  Home Office  United States       Fort Worth  ...
# 15    Harold Pawlan  Home Office  United States       Fort Worth  ...
# 23  Sandra Flanagan     Consumer  United States     Philadelphia  ...
#
#            Category  Sub-Category  \
# 3         Furniture        Tables
# 14  Office Supplies    Appliances
# 15  Office Supplies       Binders
# 23        Furniture        Chairs
#
# ...

# %%
Profit_by_Sub_Categorie.plot.bar(x='Sub-Category', y='Profit')
# Out:
# <Axes: xlabel='Sub-Category'>

# %% [markdown]
# # sales to Profit ratio

# %%
df.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Year  Order Month  Order Week
# 0  41.9136        2016          Nov           1
#
# [1 rows x 24 columns]

# %%
Sales_Profit_By_Segment = df.groupby('Segment')[['Sales', 'Profit']].sum().reset_index()
Sales_Profit_By_Segment
# Out:
#        Segment         Sales       Profit
# 0     Consumer  1.161401e+06  134119.2092
# 1    Corporate  7.061464e+05   91979.1340
# 2  Home Office  4.296531e+05   60298.6785

# %%
Sagment_Analysis = df.groupby('Segment')[['Sales','Profit']].mean()
Sagment_Analysis
# Out:
#                   Sales     Profit
# Segment
# Consumer     223.733644  25.836873
# Corporate    233.823300  30.456667
# Home Office  240.972041  33.818664

# %%
Segment_Analysis = df.groupby('Segment')[['Sales','Profit']].mean()

Segment_Analysis['Sales_to_Profit_Ratio'] = Segment_Analysis['Sales'] / Segment_Analysis['Profit']

Segment_Analysis
# Out:
#                   Sales     Profit  Sales_to_Profit_Ratio
# Segment
# Consumer     223.733644  25.836873               8.659471
# Corporate    233.823300  30.456667               7.677245
# Home Office  240.972041  33.818664               7.125416

# %%
Segment_Analysis = df.groupby('Segment')[['Sales','Profit']].mean()

Segment_Analysis['Sales_to_Profit_Ratio'] = Segment_Analysis['Sales'] / Segment_Analysis['Profit']

Segment_Analysis = Segment_Analysis[['Sales_to_Profit_Ratio']]

Segment_Analysis
# Out:
#              Sales_to_Profit_Ratio
# Segment
# Consumer                  8.659471
# Corporate                 7.677245
# Home Office               7.125416
